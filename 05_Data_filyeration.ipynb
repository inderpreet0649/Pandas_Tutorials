# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df =sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# ## Selecting single column

# %%
df["survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
df[['survived' , 'age']]
# Out:
#      survived   age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# ## Selecting multiple columns

# %%
# ek too jada columns extract karn layi 2 brackets lagniya (list pass karn layi 2 brackets use kitiya)
df[["survived","age"]]
# Out:
#      survived   age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %%
df[["survived","age","parch"]]
# Out:
#      survived   age  parch
# 0           0  22.0      0
# 1           1  38.0      0
# 2           1  26.0      0
# 3           1  35.0      0
# 4           0  35.0      0
# ..        ...   ...    ...
# 886         0  27.0      0
# 887         1  19.0      0
# 888         0   NaN      2
# 889         1  26.0      0
# 890         0  32.0      0
#
# [891 rows x 3 columns]

# %%
df['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %% [markdown]
# ### Selecting a value

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['embark_town']
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
df['embark_town'][0:10]
# Out:
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# 5     Queenstown
# 6    Southampton
# 7    Southampton
# 8    Southampton
# 9      Cherbourg
# Name: embark_town, dtype: object

# %%
df['embark_town'][0:49]
# Out:
# 0     Southampton
# 1       Cherbourg
# 2     Southampton
# 3     Southampton
# 4     Southampton
# 5      Queenstown
# 6     Southampton
# 7     Southampton
# 8     Southampton
# 9       Cherbourg
# 10    Southampton
# 11    Southampton
# 12    Southampton
# 13    Southampton
# 14    Southampton
# 15    Southampton
# 16     Queenstown
# 17    Southampton
# 18    Southampton
# 19      Cherbourg
# 20    Southampton
# 21    Southampton
# 22     Queenstown
# 23    Southampton
# 24    Southampton
# 25    Southampton
# 26      Cherbourg
# 27    Southampton
# 28     Queenstown
# 29    Southampton
# 30      Cherbourg
# 31      Cherbourg
# 32     Queenstown
# 33    Southampton
# 34      Cherbourg
# 35    Southampton
# 36      Cherbourg
# 37    Southampton
# 38    Southampton
# 39      Cherbourg
# 40    Southampton
# 41    Southampton
# 42      Cherbourg
# 43      Cherbourg
# 44     Queenstown
# 45    Southampton
# 46     Queenstown
# 47     Queenstown
# 48      Cherbourg
# ...

# %% [markdown]
# ### Selecting no. of rows

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# sample by default 1 row chakda
df.sample()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 585         1       1  female  18.0      0      2  79.65        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 585  woman       False    E  Southampton   yes  False

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df[50:100]
# Out:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 50         0       3    male   7.00      4      1   39.6875        S   Third
# 51         0       3    male  21.00      0      0    7.8000        S   Third
# 52         1       1  female  49.00      1      0   76.7292        C   First
# 53         1       2  female  29.00      1      0   26.0000        S  Second
# 54         0       1    male  65.00      0      1   61.9792        C   First
# 55         1       1    male    NaN      0      0   35.5000        S   First
# 56         1       2  female  21.00      0      0   10.5000        S  Second
# 57         0       3    male  28.50      0      0    7.2292        C   Third
# 58         1       2  female   5.00      1      2   27.7500        S  Second
# 59         0       3    male  11.00      5      2   46.9000        S   Third
# 60         0       3    male  22.00      0      0    7.2292        C   Third
# ...

# %%
df[::-1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 0           0       3    male  22.0      1      0   7.2500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[0::2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[0:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
df[50::5]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 50          0       3    male   7.0      4      1  39.6875        S   Third
# 55          1       1    male   NaN      0      0  35.5000        S   First
# 60          0       3    male  22.0      0      0   7.2292        C   Third
# 65          1       3    male   NaN      1      1  15.2458        C   Third
# 70          0       2    male  32.0      0      0  10.5000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[0:20:2]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 8          1       3  female  27.0      0      2  11.1333        S  Third
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 12         0       3    male  20.0      0      0   8.0500        S  Third
# 14         0       3  female  14.0      0      0   7.8542        S  Third
# 16         0       3    male   2.0      4      1  29.1250        Q  Third
# 18         0       3  female  31.0      1      0  18.0000        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# ## LOCATION (LOC) and iloc
#
# most imporatant TOPIC FOR INTERVIEW

# %%
d = {
    'name':['inder','preet','preety'],
    'age' :[20,21,25]
}

# %%
df = pd.DataFrame(d,index = ['A','B','C'])

# %%
df
# Out:
#      name  age
# A   inder   20
# B   preet   21
# C  preety   25

# %%
#by naming ...inn dono types se hum row uthathe hai abhi tak hum sirf column ki baat kr rhe the 
df.loc['A']
# Out:
# name    inder
# age        20
# Name: A, dtype: object

# %%
#by indexing....##interview me jrur jrur pucha jayega as isme square bracket lgti hai and inn dono me sabhi cunfuse hote hai so clear it very much
df.iloc[1]
# Out:
# name    preet
# age        21
# Name: B, dtype: object

# %%
df.loc['A']
# Out:
# name    inder
# age        20
# Name: A, dtype: object

# %%
df.iloc[1]
# Out:
# name    preet
# age        21
# Name: B, dtype: object

# %% [markdown]
# ## Filtering by index name

# %%
# loc vich asi index da name dindai like here A,B,C
df.loc['C']
# Out:
# name    preety
# age         25
# Name: C, dtype: object

# %% [markdown]
# ## Flitering by index number

# %%
# iloc vich asi idex number dai kai excess kardai like(0,1,2)
df.iloc[0]
# Out:
# name    inder
# age        20
# Name: A, dtype: object

# %%
a = df[0:1]

# %%
a
# Out:
#     name  age
# A  inder   20

# %%
df.iloc[1]
# Out:
# name    preet
# age        21
# Name: B, dtype: object

# %%
df.iloc[1,0]
# Out:
# 'preet'

# %%
# phala row filter hundi but square bracket vich comma , too baad column filter hunda (you can also do this with loc)
df.iloc[1:,]
# Out:
#      name  age
# B   preet   21
# C  preety   25

# %%
df.iloc[1:,0]
# Out:
# B     preet
# C    preety
# Name: name, dtype: object

# %%
df.iloc[1:,1]
# Out:
# B    21
# C    25
# Name: age, dtype: int64

# %%
df.loc['B',]
# Out:
# name    preet
# age        21
# Name: B, dtype: object

# %%
df.loc['B':,]
# Out:
#      name  age
# B   preet   21
# C  preety   25

# %%
df = sns.load_dataset('anagrams')

# %%
df
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
# you can change a column name to index number means you can add a column name to index number or row number
df.set_index('subidr')
# Out:
#           attnr  num1  num2  num3
# subidr
# 1       divided     2   4.0     7
# 2       divided     3   4.0     5
# 3       divided     3   5.0     6
# 4       divided     5   7.0     5
# 5       divided     4   5.0     8
# 6       divided     5   5.0     6
# 7       divided     5   4.5     6
# 8       divided     5   7.0     8
# 9       divided     2   3.0     7
# 10      divided     6   5.0     6
# 11      focused     6   5.0     6
# 12      focused     8   9.0     8
# 13      focused     6   5.0     9
# 14      focused     8   8.0     7
# 15      focused     8   8.0     7
# 16      focused     6   8.0     7
# 17      focused     7   7.0     6
# 18      focused     7   8.0     6
# 19      focused     5   6.0     6
# 20      focused     6   6.0     5

# %%
d = {
    'id' : ["A","B","C"],
    'name':['inder','preet','preety'],
    'age' :[20,21,25]
}

# %%
d
# Out:
# {'id': ['A', 'B', 'C'],
#  'name': ['inder', 'preet', 'preety'],
#  'age': [20, 21, 25]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#   id    name  age
# 0  A   inder   20
# 1  B   preet   21
# 2  C  preety   25

# %%
df.set_index('id')
# Out:
#       name  age
# id
# A    inder   20
# B    preet   21
# C   preety   25

# %%
df
# Out:
#   id    name  age
# 0  A   inder   20
# 1  B   preet   21
# 2  C  preety   25

# %%
# pandas vich data new variable vich vhange karn nal actual data cahnge ni hunda actual data vich change or save karn layi asi inplace use kardai 
df.set_index('id',inplace=True)

# %%
df
# Out:
#       name  age
# id
# A    inder   20
# B    preet   21
# C   preety   25

# %%
d ={
    'id': ['A','B','C','D','E','F'],
    'name':["inder","preet","preety","mumma",'papa','harpie'],
    'age':[20,23,10,18,20,21]
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#   id    name  age
# 0  A   inder   20
# 1  B   preet   23
# 2  C  preety   10
# 3  D   mumma   18
# 4  E    papa   20
# 5  F  harpie   21

# %%
df.set_index('id',inplace= True)

# %%
df
# Out:
#       name  age
# id
# A    inder   20
# B    preet   23
# C   preety   10
# D    mumma   18
# E     papa   20
# F   harpie   21

# %%
# ethai phala row excess kiti than column
df.loc[['A','B'],'age']
# Out:
# id
# A    20
# B    23
# Name: age, dtype: int64

# %%
df.loc[['A','B'],]
# Out:
#      name  age
# id
# A   inder   20
# B   preet   23

# %%
df.loc[['D','E'],'name']
# Out:
# id
# D    mumma
# E     papa
# Name: name, dtype: object

# %%
df =sns.load_dataset('taxis')

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.to_csv('data/taxis.csv')

# %%
df.iloc[0:10]
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7 2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8 2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9 2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0  1.00
#
#    tolls  total   color      payment                pickup_zone  \
# 0    0.0  12.95  yellow  credit card            Lenox Hill West
# ...

# %%
df.iloc[0:10,0:8]
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7 2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8 2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9 2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0  1.00
#
#    tolls  total
# 0    0.0  12.95
# 1    0.0   9.30
# 2    0.0  14.16
# 3    0.0  36.95
# 4    0.0  13.40
# 5    0.0  12.96
# ...

# %% [markdown]
# ## Filtering data through boolean manipulation

# %%
df[df['total']>50]
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 42   2019-03-30 23:59:14 2019-03-30 23:59:17           1      0.00  80.0
# 56   2019-03-05 17:57:00 2019-03-05 18:45:25           2     19.59  52.0
# 111  2019-03-15 10:56:56 2019-03-15 11:37:02           1     11.93  39.5
# 128  2019-03-06 19:29:56 2019-03-06 20:08:36           1     10.80  36.0
# 162  2019-03-06 17:36:48 2019-03-06 18:43:39           2     17.10  52.0
# ...                  ...                 ...         ...       ...   ...
# 6362 2019-03-08 03:34:43 2019-03-08 04:20:37           1     21.37  62.5
# 6393 2019-03-10 18:33:13 2019-03-10 19:32:38           1      0.00  71.2
# 6398 2019-03-17 13:07:29 2019-03-17 13:51:56           1     18.39  50.5
# 6400 2019-03-22 17:41:23 2019-03-22 18:26:00           1     13.77  43.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
#
#         tip  tolls   total   color      payment                pickup_zone  \
# ...

# %% [markdown]
# ## Symbol for and = & and = symbol for or = |

# %%
df[(df['color']=='green') & (df['total']>50)]
# Out:
#                   pickup             dropoff  passengers  distance    fare  \
# 5457 2019-03-17 18:02:49 2019-03-17 18:33:14           1     12.79   38.50
# 5458 2019-03-30 20:59:25 2019-03-30 21:46:52           1     24.48   63.53
# 5463 2019-03-22 14:56:45 2019-03-22 16:09:50           1     18.91   61.00
# 5495 2019-03-20 07:03:00 2019-03-20 07:54:47           1     16.71   50.74
# 5567 2019-03-07 00:28:57 2019-03-07 02:02:55           1     25.51   93.50
# 5648 2019-03-19 14:21:35 2019-03-19 15:51:28           2     33.46  150.00
# 5654 2019-03-30 22:13:58 2019-03-30 22:47:41           1     18.89   44.20
# 5678 2019-03-15 20:34:02 2019-03-15 20:34:10           1      0.00   52.00
# 5702 2019-03-23 14:29:29 2019-03-23 15:21:09           1     14.47   46.50
# 5708 2019-03-04 09:42:07 2019-03-04 10:35:59           1     18.60   58.00
# 5728 2019-03-01 17:07:09 2019-03-01 18:05:41           1     21.27   65.59
# ...

# %%
df[(df['passengers']<=2) & (df['pickup_zone']=='Jamaica') & (df['pickup_borough']=='Queens')& (df['distance']<=5)]
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 5660 2019-03-13 14:35:50 2019-03-13 14:44:00           1      1.53   7.5
# 5725 2019-03-01 06:42:52 2019-03-01 07:01:35           1      4.64  17.0
# 5825 2019-03-06 17:38:46 2019-03-06 18:01:32           1      4.97  19.0
# 6162 2019-03-28 18:15:04 2019-03-28 18:25:26           1      2.02   9.5
# 6237 2019-03-03 03:21:24 2019-03-03 03:27:41           1      2.09   8.0
# 6314 2019-03-28 22:36:04 2019-03-28 22:36:07           1      0.00  25.0
#
#        tip  tolls  total  color      payment pickup_zone     dropoff_zone  \
# 5660  0.00    0.0   8.30  green         cash     Jamaica     Baisley Park
# 5725  0.00    0.0  17.80  green         cash     Jamaica  Cambria Heights
# 5825  5.20    0.0  26.00  green  credit card     Jamaica  Cambria Heights
# 6162  0.00    0.0  11.30  green  credit card     Jamaica     Baisley Park
# 6237  1.86    0.0  11.16  green  credit card     Jamaica    South Jamaica
# ...

# %% [markdown]
# #### Homework

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df[(df['species']=='Gentoo')]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 220  Gentoo  Biscoe            46.1           13.2              211.0
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 220       4500.0  Female
# 221       5700.0    Male
# 222       4450.0  Female
# ...

# %%
df= df.dropna(subset=['sex'])

# %%
# df = df[df['sex'].notna()]

# %%
df[(df['species']=='Gentoo')& (df['bill_length_mm']<=50) & (df['bill_depth_mm']<=15) & (df['flipper_length_mm']<=250)]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 220  Gentoo  Biscoe            46.1           13.2              211.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# 225  Gentoo  Biscoe            46.5           13.5              210.0
# 226  Gentoo  Biscoe            45.4           14.6              211.0
# ..      ...     ...             ...            ...                ...
# 328  Gentoo  Biscoe            43.3           14.0              208.0
# 334  Gentoo  Biscoe            46.2           14.1              217.0
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
#
#      body_mass_g     sex
# 220       4500.0  Female
# 222       4450.0  Female
# 224       5400.0    Male
# ...

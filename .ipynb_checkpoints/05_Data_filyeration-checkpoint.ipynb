# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df =sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df[['survived' , 'age']]
# Out:
#      survived   age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %%
df[['survived','age','fare']]
# Out:
#      survived   age     fare
# 0           0  22.0   7.2500
# 1           1  38.0  71.2833
# 2           1  26.0   7.9250
# 3           1  35.0  53.1000
# 4           0  35.0   8.0500
# ..        ...   ...      ...
# 886         0  27.0  13.0000
# 887         1  19.0  30.0000
# 888         0   NaN  23.4500
# 889         1  26.0  30.0000
# 890         0  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
df['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %% [markdown]
# ### Selecting a value

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['embark_town'][0:10]
# Out:
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# 5     Queenstown
# 6    Southampton
# 7    Southampton
# 8    Southampton
# 9      Cherbourg
# Name: embark_town, dtype: object

# %%
df['embark_town'][0:49]
# Out:
# 0     Southampton
# 1       Cherbourg
# 2     Southampton
# 3     Southampton
# 4     Southampton
# 5      Queenstown
# 6     Southampton
# 7     Southampton
# 8     Southampton
# 9       Cherbourg
# 10    Southampton
# 11    Southampton
# 12    Southampton
# 13    Southampton
# 14    Southampton
# 15    Southampton
# 16     Queenstown
# 17    Southampton
# 18    Southampton
# 19      Cherbourg
# 20    Southampton
# 21    Southampton
# 22     Queenstown
# 23    Southampton
# 24    Southampton
# 25    Southampton
# 26      Cherbourg
# 27    Southampton
# 28     Queenstown
# 29    Southampton
# 30      Cherbourg
# 31      Cherbourg
# 32     Queenstown
# 33    Southampton
# 34      Cherbourg
# 35    Southampton
# 36      Cherbourg
# 37    Southampton
# 38    Southampton
# 39      Cherbourg
# 40    Southampton
# 41    Southampton
# 42      Cherbourg
# 43      Cherbourg
# 44     Queenstown
# 45    Southampton
# 46     Queenstown
# 47     Queenstown
# 48      Cherbourg
# ...

# %% [markdown]
# ### Selecting no. of rows

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sample()
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked   class  who  \
# 145         0       2  male  19.0      1      1  36.75        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# 145        True  NaN  Southampton    no  False

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df[50:100]
# Out:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 50         0       3    male   7.00      4      1   39.6875        S   Third
# 51         0       3    male  21.00      0      0    7.8000        S   Third
# 52         1       1  female  49.00      1      0   76.7292        C   First
# 53         1       2  female  29.00      1      0   26.0000        S  Second
# 54         0       1    male  65.00      0      1   61.9792        C   First
# 55         1       1    male    NaN      0      0   35.5000        S   First
# 56         1       2  female  21.00      0      0   10.5000        S  Second
# 57         0       3    male  28.50      0      0    7.2292        C   Third
# 58         1       2  female   5.00      1      2   27.7500        S  Second
# 59         0       3    male  11.00      5      2   46.9000        S   Third
# 60         0       3    male  22.00      0      0    7.2292        C   Third
# ...

# %%
df[::-1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 0           0       3    male  22.0      1      0   7.2500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[0::2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[0:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %% [markdown]
# ## LOC and iloc
#
# most imporatant

# %%
d = {
    'name':['inder','preet','preety'],
    'age' :[20,21,25]
}

# %%
df = pd.DataFrame(d,index = ['A','B','C'])

# %%
df
# Out:
#      name  age
# A   inder   20
# B   preet   21
# C  preety   25

# %%
#by naming...inn dono types se hum row uthathe hai abhi tak hum sirf column ki baat kr rhe the 
df.loc['A']
# Out:
# name    inder
# age        20
# Name: A, dtype: object

# %%
#by indexing....##interview me jrur jrur pucha jayega as isme square bracket lgti hai and inn dono me sabhi cunfuse hote hai so clear it very much
df.iloc[1]
# Out:
# name    preet
# age        21
# Name: B, dtype: object

# %%
df.loc['A']
# Out:
# name    inder
# age        20
# Name: A, dtype: object

# %%
0
